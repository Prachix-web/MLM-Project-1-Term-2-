# %% [markdown]
# # Project Report
#
# ## Title: Build Unsupervised Learning Models using Python: Clustering {Hierarchical | K-Means}
#
# ### Prepared By:
# - **055029**: Prachi Lakra
# - **055060**: Chirag Singla
#
# ### Group Number-**20**
#
# ### Term-**2**
#
# ### Project-**Project 1**

# %% [markdown]
# # 1. Project Information

# %% [markdown]
# This project centers on the examination of a dataset related to import-export transactions. The aim is to discover trends, detect anomalies, and extract actionable insights that can support enhanced decision-making processes.

# %% [markdown]
# ```
# # Approach
# ```
#
# The project employs a blend of statistical and machine learning methodologies to analyze the data and derive significant insights. The ultimate goal is to propose recommendations for enhancing trade efficiency and pinpointing key market segments or anomalies that may impact business strategies.

# %% [markdown]
# # 2. Description of Data
#  The structure of the data includes multiple columns related to import-export transactions.

# %% [markdown]
# ### Subjective Description of the Data
#
# The dataset under analysis comprises **16 columns** and **15,000 rows**, representing transactional records in the domain of import-export activities. Below is a subjective interpretation of the dataset's attributes:
#
# 1. **Transaction_ID**:
#    - A unique identifier for each transaction, essential for tracking and referencing specific records.
#
#
# 2. **Country**:
#    - Specifies the country involved in the transaction, offering insights into geographic distribution and facilitating the analysis of trade patterns across regions.
#
#
# 3. **Product**:
#    - Provides details about the goods involved in the trade, enabling the identification of high-demand or high-value products.
#
#
# 4. **Import_Export**:
#    - Indicates whether the transaction is an import or export, facilitating the study of trade flow directions.
#
#
# 5. **Quantity**:
#    - Reflects the volume of goods traded in unit quantities, aiding in the assessment of transaction scale.
#
#
# 6. **Value**:
#    - Represents the monetary value of the transaction, crucial for evaluating trade impact and market size.
#
#
# 7. **Date**:
#    - The transaction date, which supports time-series analysis to uncover trends, seasonality, and anomalies in trade activities.
#
#
# 8. **Category**:
#    - A broad classification of the product, enabling aggregated insights through segmentation.
#
#
# 9. **Port**:
#    - Indicates the port of entry or exit, critical for understanding logistics and transportation patterns.
#
#
# 10. **Customs_Code**:
#     - A numerical classification assigned by customs, supporting regulatory compliance analysis.
#
#
# 11. **Weight**:
#     - Denotes the weight of traded goods, often in kilograms or tons, complementing the Quantity column for logistics planning.
#
#
# 12. **Shipping_Method**:
#     - Describes the mode of transport (e.g., air, sea, or land), pivotal for analyzing cost-efficiency and transit times.
#
# 13. **Supplier**:
#     - Identifies the provider of goods, aiding in the evaluation of supply chains and vendor management.
#
#
# 14. **Customer**:
#     - Specifies the recipient or buyer of goods, offering insights into demand-side dynamics and customer segmentation.
#
#
# 15. **Invoice_Number**:
#     - A unique identifier for billing and payment, ensuring traceability and financial accountability.
#
#
# 16. **Payment_Terms**:
#     - Describes the terms of payment, aiding in the analysis of financial arrangements and credit practices.

# %% [markdown]
# # 3. Project Objectives | Problem Statements
#
# 1. **Identify Product Clusters**
#    - Use unsupervised learning techniques to group product categories that are frequently exported or imported together, uncovering relationships and co-occurrence patterns in trade data.
#
# 2. **Discover Market Segmentation**
#    - Analyze trade patterns to identify markets with similar buying or selling behaviors, enabling targeted marketing and resource allocation strategies.
#
# 3. **Detect Anomalies in Transactions**
#    - Identify unusual trends, such as price fluctuations, abnormally high or low quantities, or irregular trade routes, which could indicate potential errors, fraud, or unique opportunities.
#
# 4. **Optimize Trade Routes and Shipping Methods**
#    - Evaluate patterns in port usage and shipping methods to optimize logistics, reduce costs, and improve delivery times.
#
# 5. **Uncover Seasonal Trends**
#    - Analyze time-series data to detect seasonal variations or recurring patterns in trade volumes for better demand forecasting and inventory management.
#
# 6. **Spot High-Value Product Groups**
#    - Cluster products and categories to identify high-value goods that drive trade revenues, aiding in prioritization and strategic focus.
#
# 7. **Explore Supplier-Customer Relationships**
#    - Investigate transactional data to detect consistent partnerships or dependencies between suppliers and customers for improved supply chain management.
#
# 8. **Evaluate Payment Practices**
#    - Analyze patterns in payment terms and invoice values to identify common practices, delayed payments, or potential risks in financial transactions.

# %% [markdown]
# # 4. **Analysis of Data**:
#    - The dataset underwent preprocessing, normalization, and clustering through K-Means, Hierarchical Clustering, and Agglomerative Clustering techniques. Silhouette scores were computed to determine the optimal number of clusters. Visualization tools like the elbow plot and dendrogram helped identify cluster boundaries and relationships.

# %% [markdown]
# # **5 Observations & Findings**
#
# Based on the provided dendrogram and silhouette score plots:
#
# ## **Observations**
# 1. **Hierarchical Clustering (Dendrogram)**:
#    - Clear hierarchical structures are evident, with significant vertical gaps suggesting potential cluster divisions.
#   - A threshold can be set to determine the optimal number of clusters.
#
#
# 2. **Silhouette Scores**:
#    - The silhouette scores decrease as the number of clusters increases, indicating a diminishing cluster compactness and separation.
#    - A high silhouette score for 2 clusters suggests that the dataset is well-separated into two distinct groups.
#    - Adding more clusters reduces the score, which might imply over-segmentation or less meaningful divisions.
#
# ---
#
# ## **Findings**
# 1. **Optimal Clustering**:
#    - Two clusters strike a balance between separation and compactness. However, additional clusters provide finer segmentation based on specific needs.
#
#
# 2. **Cluster Characteristics**:
#    - Identified clusters represent groups of similar data points, such as product categories or market segments.
#
#
# 3. **Trade-off Between Simplicity and Detail**:
#    - While simpler segmentation (e.g., two clusters) is interpretable, higher granularity (e.g., 3–5 clusters) may better suit targeted use cases.

# %% [markdown]
# # 6 Manegerial Insights
#
# ### Managerial Insights
#
# 1. **Presence of Two Distinct Groups**:
#    - The silhouette score analysis reveals that the dataset can be optimally divided into **two distinct groups or clusters**. This indicates that the data points within each group share significant similarities, while the groups themselves are well-separated.
#
# 2. **Strategic Implications of the Two Groups**:
#    - These two groups may represent key segments such as:
#      - **Product Categories**: Two broad product types dominating import/export transactions.
#      - **Market Segments**: Distinct buyer or supplier groups with varying trade behaviors.
#      - **Geographical Trends**: Regions with different trade volumes or patterns.
#
# 3. **Simplified Segmentation**:
#    - Keeping two clusters allows for a high-level segmentation, making it easier to develop targeted strategies without overcomplicating the analysis.
#
# 4. **Actionable Strategies**:
#    - Focus on **tailored marketing strategies** for each group to maximize trade efficiency.
#    - Design **customized supply chain processes** for each group to optimize resource allocation and logistics.
#    - Investigate outliers within each group to identify unique opportunities or potential risks.
#
# 5. **Validation of Cluster Use**:
#    - Before finalizing strategies, validate the group composition with domain knowledge to ensure the clustering reflects meaningful trade characteristics.
#
# 6. **Further Insights with Supervised Learning**:
#    - Implementing supervised learning can refine these clusters by predicting specific outcomes, such as trade volume, revenue, or anomaly detection, enabling precise strategies for targeted business optimization.

# %% [markdown]
# ## Importing Data

# %%
import io
import pandas as pd
import requests

# Replace with your Google Drive file ID extracted from the shared link.
CP00_file_id = '1J95fbfZCEB0nx9Zv437Nbm4bwo3JQaUM'  # Extracted file ID.

# Construct the download URL for CP00.
CP00_url = f"https://drive.google.com/uc?id={CP00_file_id}&export=download"

# Download the file content.
CP00_response = requests.get(CP00_url)
CP00_response.raise_for_status()  # Raise an exception for bad responses (4xx or 5xx)

# Read the file content into a Pandas DataFrame.
# Assuming it's a CSV file.
CP00_data = pd.read_csv(io.StringIO(CP00_response.text))

# Now you can work with the data in the Pandas DataFrame 'CP00_data'.
# For example, you can print the first few rows.
print(CP00_data.head())
# Out:
#                          Transaction_ID           Country    Product  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3  f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4  e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
#
#   Import_Export  Quantity    Value        Date     Category              Port  \
# 0        Export      1979  9506.57  07-12-2023    Machinery        Robertbury
# 1        Export      5763  7100.91  04-04-2023     Clothing          Shahport
# 2        Import      5740  2450.34  21-08-2024  Electronics  South Joshuatown
# 3        Export      2592  7226.42  09-05-2022    Furniture          Adamfort
# 4        Export      2622  2817.29  03-04-2023  Electronics         Juliebury
#
#    Customs_Code   Weight Shipping_Method                         Supplier  \
# ...

# %% [markdown]
# ## Checking structure of Data

# %%
CP00_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %%
CP00_data.head(3)
# Out:
#                          Transaction_ID   Country    Product Import_Export  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd  Colombia   describe        Export
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455     Chile  president        Export
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662    Turkey        far        Import
#
#    Quantity    Value        Date     Category              Port  Customs_Code  \
# 0      1979  9506.57  07-12-2023    Machinery        Robertbury        620537
# 1      5763  7100.91  04-04-2023     Clothing          Shahport        927600
# 2      5740  2450.34  21-08-2024  Electronics  South Joshuatown        299258
#
#     Weight Shipping_Method                         Supplier       Customer  \
# 0  4248.65             Air  Garrison, Hubbard and Hendricks      Seth Hall
# 1  4340.81             Air                        Webb-Mack  Kimberly Ryan
# 2  4538.41             Air        Mendez, Jones and Johnson     Ryan Silva
#
#    Invoice_Number     Payment_Terms
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Data Sampling

# %%
# Sample 5001 of the data
CP00_sample_data_0 = CP00_data.sample(n=5001, random_state=550029)

# CP00_display the first few rows of the sample
CP00_sample_data_0.head(3)
# Out:
#                              Transaction_ID        Country Product  \
# 8989   1a8fbfdb-a941-404b-bb42-a6d69ecc67c8  Cote d'Ivoire   until
# 14190  fe7b04bb-1327-461f-8075-abaf0b4a238e       Ethiopia  enough
# 14476  d6874e97-ee66-4ef8-9516-43fb0fbe731c        Belgium     eye
#
#       Import_Export  Quantity    Value        Date   Category  \
# 8989         Import      8654  2016.76  29-09-2022  Machinery
# 14190        Import      2854  3619.70  17-10-2019  Machinery
# 14476        Export      7444  2982.23  20-02-2024  Machinery
#
#                       Port  Customs_Code   Weight Shipping_Method  \
# 8989            Port David        111266  3129.66             Sea
# 14190         Jameschester        917044  4205.58            Land
# 14476  West Suzannechester        571524  4307.11             Sea
#
#              Supplier       Customer  Invoice_Number Payment_Terms
# 8989     Hudson Group     Ryan Glass        10150958       Prepaid
# ...

# %%
def CP00_check_unique_values(dataframe):
    """
    Calculate the number of unique values, total values,
    and percentage of unique values for each column in the DataFrame.

    Args:
        dataframe (pd.DataFrame): The input DataFrame.

    Returns:
        pd.DataFrame: A summary DataFrame with unique value statistics.
    """
    # Calculate unique values, total values, and percentage of unique values
    unique_counts = dataframe.nunique()
    total_counts = dataframe.count()
    percentages = (unique_counts / total_counts) * 100

    # Combine the results into a DataFrame for better CP00_display
    summary_CP00_df = pd.DataFrame({
        'Unique Values': unique_counts,
        'Total Values': total_counts,
        'Percentage (%)': percentages
    })

    return summary_CP00_df

# %% [markdown]
# ## Categorizing Variables

# %%
CP00_sample_data_0.columns
# Out:
# Index(['Transaction_ID', 'Country', 'Product', 'Import_Export', 'Quantity',
#        'Value', 'Date', 'Category', 'Port', 'Customs_Code', 'Weight',
#        'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number',
#        'Payment_Terms'],
#       dtype='object')

# %%
# Check whether a Variable is index or not
CP00_check_unique_values(CP00_sample_data_0)
# Out:
#                  Unique Values  Total Values  Percentage (%)
# Transaction_ID            5001          5001      100.000000
# Country                    243          5001        4.859028
# Product                    965          5001       19.296141
# Import_Export                2          5001        0.039992
# Quantity                  3910          5001       78.184363
# Value                     4991          5001       99.800040
# Date                      1704          5001       34.073185
# Category                     5          5001        0.099980
# Port                      4274          5001       85.462907
# Customs_Code              4978          5001       99.540092
# Weight                    4979          5001       99.560088
# Shipping_Method              3          5001        0.059988
# Supplier                  4525          5001       90.481904
# Customer                  4861          5001       97.200560
# ...

# %%
CP00_columns= ['Country', 'Product', 'Import_Export', 'Quantity', 'Value', 'Category', 'Port', 'Weight', 'Shipping_Method', 'Payment_Terms']

# %%
CP00_sample_data_1 = CP00_sample_data_0[CP00_columns]
CP00_sample_data_1.head(3)
# Out:
#              Country Product Import_Export  Quantity    Value   Category  \
# 8989   Cote d'Ivoire   until        Import      8654  2016.76  Machinery
# 14190       Ethiopia  enough        Import      2854  3619.70  Machinery
# 14476        Belgium     eye        Export      7444  2982.23  Machinery
#
#                       Port   Weight Shipping_Method Payment_Terms
# 8989            Port David  3129.66             Sea       Prepaid
# 14190         Jameschester  4205.58            Land       Prepaid
# 14476  West Suzannechester  4307.11             Sea        Net 60

# %%
# Verify whether all variables are non-index variables
CP00_check_unique_values(CP00_sample_data_1)
# Out:
#                  Unique Values  Total Values  Percentage (%)
# Country                    243          5001        4.859028
# Product                    965          5001       19.296141
# Import_Export                2          5001        0.039992
# Quantity                  3910          5001       78.184363
# Value                     4991          5001       99.800040
# Category                     5          5001        0.099980
# Port                      4274          5001       85.462907
# Weight                    4979          5001       99.560088
# Shipping_Method              3          5001        0.059988
# Payment_Terms                4          5001        0.079984

# %%
CP00_categorical_columns = ['Country', 'Product', 'Import_Export', 'Category', 'Port', 'Shipping_Method', 'Payment_Terms']
CP00_non_categorical_columns = ['Quantity', 'Value', 'Weight']

# %%
CP00_categorical_ordinal_columns = []
CP00_categorical_nominal_columns = ['Country', 'Product', 'Category', 'Port', 'Shipping_Method', 'Payment_Terms', 'Import_Export']

# %% [markdown]
# ## Imputation

# %% [markdown]
# ### Checking Missing Percentage

# %%
import pandas as pd
import numpy as np

# Sample 5001 of the data (Ensure CP00_data is already defined)
CP00_sample_data_0 = CP00_data.sample(n=5001, random_state=55002)

# Define columns for sampling (replace with actual column names)
CP00_columns = CP00_data.columns  # Replace with the relevant column selection if needed
CP00_sample_data_1 = CP00_sample_data_0[CP00_columns]

# Function to calculate missing data information
def CP00_missing_data_info(CP00_sample_data):
    # Calculate missing count and percentage
    CP00_missing_count = CP00_sample_data.isnull().sum()
    CP00_missing_percentage = (CP00_missing_count / len(CP00_sample_data)) * 100

    # Create a DataFrame with missing data information
    CP00_missing_info = pd.DataFrame({
        'CP00_Variable': CP00_sample_data.columns,
        'CP00_Missing_Count': CP00_missing_count.values,
        'CP00_Missing_Percentage': CP00_missing_percentage.values
    }).reset_index(drop=True)

    # Format the percentage column
    CP00_missing_info['CP00_Missing_Percentage'] = CP00_missing_info['CP00_Missing_Percentage'].round(2).astype(str) + '%'

    return CP00_missing_info

# Call the function
missing_info = CP00_missing_data_info(CP00_sample_data_1)

# Display the missing data information
print(missing_info)
# Out:
#       CP00_Variable  CP00_Missing_Count CP00_Missing_Percentage
# 0    Transaction_ID                   0                    0.0%
# 1           Country                   0                    0.0%
# 2           Product                   0                    0.0%
# 3     Import_Export                   0                    0.0%
# 4          Quantity                   0                    0.0%
# 5             Value                   0                    0.0%
# 6              Date                   0                    0.0%
# 7          Category                   0                    0.0%
# 8              Port                   0                    0.0%
# 9      Customs_Code                   0                    0.0%
# 10           Weight                   0                    0.0%
# 11  Shipping_Method                   0                    0.0%
# 12         Supplier                   0                    0.0%
# 13         Customer                   0                    0.0%
# ...

# %% [markdown]
# ### Drop Variable

# %%
import pandas as pd

# Sample dataset creation (replace with your actual dataset loading)
# Assuming CP00_data is already loaded. Replace this with the actual dataset if needed.
CP00_data = pd.DataFrame({
    'column1': [1, 2, None, 4, 5],
    'column2': ['A', 'B', None, 'A', 'B'],
    'column3': [None, 1.5, 2.5, None, 4.5],
    'column4': [10, 20, 30, None, None]
})

# Sampling 5001 rows (or less if the dataset is smaller)
CP00_sample_data_0 = CP00_data.sample(n=min(5001, len(CP00_data)), random_state=55002)

# Define columns
CP00_categorical_columns = ['column2']  # Replace with actual categorical column names
CP00_non_categorical_columns = ['column1', 'column3', 'column4']  # Replace with actual non-categorical columns
CP00_columns = CP00_categorical_columns + CP00_non_categorical_columns

# Copying data for further processing
CP00_sample_data_1 = CP00_sample_data_0.copy()

# Function to omit variables with more than a threshold of missing values and log omitted variables
def CP00_clean_data_with_logging(
    CP00_sample_data,
    CP00_categorical_columns,
    CP00_non_categorical_columns,
    CP00_columns,
    missing_threshold=50
):
    # Calculate missing percentage for each variable
    CP00_missing_percentage = (CP00_sample_data.isnull().sum() / len(CP00_sample_data)) * 100

    # Identify variables to omit (missing percentage > threshold)
    variables_to_omit = CP00_missing_percentage[CP00_missing_percentage > missing_threshold]

    # Create a DataFrame for omitted variables
    omitted_info = []
    for variable, percentage in variables_to_omit.items():
        if variable in CP00_categorical_columns:
            source = "CP00_categorical_columns"
        elif variable in CP00_non_categorical_columns:
            source = "CP00_non_categorical_columns"
        elif variable in CP00_columns:
            source = "CP00_columns"
        else:
            source = "Unknown"

        omitted_info.append({
            "Variable": variable,
            "Missing_Percentage": round(percentage, 2),
            "Omitted_From": source
        })

    # Convert omitted info to DataFrame
    CP00_omitted_df = pd.DataFrame(omitted_info)

    # Identify variables to keep
    variables_to_keep = CP00_missing_percentage[CP00_missing_percentage <= missing_threshold].index.tolist()

    # Filter the dataset
    CP00_sample_data_cleaned = CP00_sample_data[variables_to_keep]

    # Update the lists (only keep variables that are not omitted)
    CP00_columns[:] = [col for col in CP00_columns if col in variables_to_keep]
    CP00_categorical_columns[:] = [col for col in CP00_categorical_columns if col in variables_to_keep]
    CP00_non_categorical_columns[:] = [col for col in CP00_non_categorical_columns if col in variables_to_keep]

    # Print the DataFrame of omitted variables
    print("Variables Omitted Due to Missing Values (> {}%):".format(missing_threshold))
    print(CP00_omitted_df)

    return CP00_sample_data_cleaned

# Call the cleaning function
CP00_sample_data_cleaned = CP00_clean_data_with_logging(
    CP00_sample_data_1,
    CP00_categorical_columns,
    CP00_non_categorical_columns,
    CP00_columns,
    missing_threshold=50
)

# Display the cleaned data
print("\nCleaned Data:")
print(CP00_sample_data_cleaned.head())
# Out:
# Variables Omitted Due to Missing Values (> 50%):
# Empty DataFrame
# Columns: []
# Index: []
#
# Cleaned Data:
#    column1 column2  column3  column4
# 2      NaN    None      2.5     30.0
# 3      4.0       A      NaN      NaN
# 1      2.0       B      1.5     20.0
# 0      1.0       A      NaN     10.0
# 4      5.0       B      4.5      NaN

# %%
CP00_sample_data_dropped_variable = CP00_sample_data_1[CP00_columns]

# %% [markdown]
# ### Categorical Imputation

# %%
from sklearn.impute import SimpleImputer

# Make a copy of the dataset (assuming CP00_sample_data_dropped_variable is defined)
CP00_sample_data_imputed = CP00_sample_data_dropped_variable.copy()

# Initialize SimpleImputer with most_frequent strategy
CP00_imputer = SimpleImputer(strategy='most_frequent')

# Apply imputation on categorical columns
CP00_sample_data_imputed[CP00_categorical_columns] = CP00_imputer.fit_transform(
    CP00_sample_data_imputed[CP00_categorical_columns]
)

# %% [markdown]
# ### Non Categorical Imputation

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer

def CP00_impute_columns_with_mean_or_median(CP00_df, columns):
    for col in columns:
        # Ensure column is numeric
        CP00_df[col] = pd.to_numeric(CP00_df[col], errors='coerce')

        # Replace invalid values with NaN
        CP00_df[col].replace([np.inf, -np.inf], np.nan, inplace=True)

        # Skip if column has no missing values
        if CP00_df[col].isnull().sum() == 0:
            continue

        # Calculate mean and median
        CP00_col_mean = CP00_df[col].mean()
        CP00_col_median = CP00_df[col].median()

        # Choose strategy based on significant difference
        if abs(CP00_col_mean - CP00_col_median) / max(abs(CP00_col_mean), abs(CP00_col_median)) > 0.1:  # Significant difference
            print(f"Imputing '{col}' with median (significant difference between mean and median)")
            CP00_imputer = SimpleImputer(strategy='median')
        else:
            print(f"Imputing '{col}' with mean (no significant difference between mean and median)")
            CP00_imputer = SimpleImputer(strategy='mean')

        # Apply the CP00_imputer
        CP00_df[[col]] = CP00_imputer.fit_transform(CP00_df[[col]])

    return CP00_df

# Assuming CP00_sample_data_imputed and CP00_non_categorical_columns are defined
CP00_sample_data_imputed = CP00_impute_columns_with_mean_or_median(CP00_sample_data_imputed, CP00_non_categorical_columns)
# Out:
# Imputing 'column1' with mean (no significant difference between mean and median)
# Imputing 'column3' with median (significant difference between mean and median)
# Imputing 'column4' with mean (no significant difference between mean and median)

# %% [markdown]
# ### Verify Missing Percetage = 0

# %%
CP00_missing_data_info(CP00_sample_data_imputed)
# Out:
#   CP00_Variable  CP00_Missing_Count CP00_Missing_Percentage
# 0       column2                   1                   20.0%
# 1       column1                   0                    0.0%
# 2       column3                   0                    0.0%
# 3       column4                   0                    0.0%

# %% [markdown]
# ## Numerical Encoding

# %% [markdown]
# ### Ordinal/Nominal Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# Define order for ordinal columns
CP00_ordinal_categories = [
    # Example:
    # ['B', 'A']  # 'A' is superior to 'B' (encoded as 1 for 'A' and 0 for 'B')
]

# Initialize OrdinalEncoder for ordinal columns with specified order
ordinal_encoder_ordinal = OrdinalEncoder(categories=CP00_ordinal_categories)

# Initialize OrdinalEncoder for nominal columns (order does not matter)
ordinal_encoder_nominal = OrdinalEncoder()

# Make a copy of the DataFrame
CP00_sample_data_ordinally_encoded = CP00_sample_data_imputed.copy()

# Verify and filter the columns
CP00_categorical_nominal_columns = [
    col for col in CP00_categorical_nominal_columns if col in CP00_sample_data_ordinally_encoded.columns
]

# Encode ordinal columns
CP00_sample_data_ordinally_encoded[CP00_categorical_ordinal_columns] = ordinal_encoder_ordinal.fit_transform(
    CP00_sample_data_ordinally_encoded[CP00_categorical_ordinal_columns].astype(str)
)

# Encode nominal columns
CP00_sample_data_ordinally_encoded[CP00_categorical_nominal_columns] = ordinal_encoder_nominal.fit_transform(
    CP00_sample_data_ordinally_encoded[CP00_categorical_nominal_columns].astype(str)
)

# Display the encoded DataFrame
print("DataFrame with Encoded Categorical Variables:")
print(CP00_sample_data_ordinally_encoded.head())
# Out:
# DataFrame with Encoded Categorical Variables:
#   column2  column1  column3  column4
# 2    None      3.0      2.5     30.0
# 3       A      4.0      2.5     20.0
# 1       B      2.0      1.5     20.0
# 0       A      1.0      2.5     10.0
# 4       B      5.0      4.5     20.0

# %% [markdown]
# ## Transformation

# %%
import numpy as np
from scipy.stats import boxcox
from sklearn.preprocessing import PowerTransformer
import pandas as pd

# Function to handle transformations based on distribution characteristics
def apply_transformations(CP00_sample_data, columns):
    # Initialize a list to store transformation logs
    CP00_transformation_logs = []

    for column in columns:
        # Compute CP00_skewness and CP00_kurtosis
        CP00_skewness = CP00_sample_data[column].skew()
        CP00_kurtosis = CP00_sample_data[column].kurt()
        CP00_action = "None"  # Default CP00_action

        # Handle Right Skew (Positive Skew)
        if CP00_skewness > 1:
            CP00_action = "Log Transformation"
            CP00_sample_data[column] = np.log1p(CP00_sample_data[column])

        # Handle Left Skew (Negative Skew)
        elif CP00_skewness < -1:
            CP00_action = "Reflect and Log Transformation"
            CP00_sample_data[column] = np.log1p(CP00_sample_data[column].max() - CP00_sample_data[column])

        # Handle High Kurtosis (Heavy Tails)
        if CP00_kurtosis > 3:
            try:
                CP00_action = "Box-Cox Transformation"
                CP00_sample_data[column], _ = boxcox(CP00_sample_data[column].clip(lower=1))
            except ValueError:
                CP00_action = "Box-Cox Failed, Applied Yeo-Johnson"
                transformer = PowerTransformer(method='yeo-johnson')
                CP00_sample_data[column] = transformer.fit_transform(CP00_sample_data[[column]])

        # Handle Low Kurtosis (Light Tails)
        elif CP00_kurtosis < 3 and CP00_action == "None":
            CP00_action = "Yeo-Johnson Transformation"
            transformer = PowerTransformer(method='yeo-johnson')
            CP00_sample_data[column] = transformer.fit_transform(CP00_sample_data[[column]])

        # Append the log entry
        CP00_transformation_logs.append({
            'Column Name': column,
            'Skewness': CP00_skewness,
            'Kurtosis': CP00_kurtosis,
            'Action Taken': CP00_action
        })

    # Create a DataFrame for transformation logs
    transformation_log_CP00_df = pd.DataFrame(CP00_transformation_logs)
    return CP00_sample_data, transformation_log_CP00_df

# Example usage with CP00_sample_data_encoded
CP00_sample_data_encoded = CP00_sample_data_ordinally_encoded.copy()
CP00_sample_data_encoded, CP00_transformation_logs = apply_transformations(CP00_sample_data_encoded, CP00_non_categorical_columns)

# Display the transformation log DataFrame
print("Transformation Log:")
print(CP00_transformation_logs)
# Out:
# Transformation Log:
#   Column Name  Skewness  Kurtosis                Action Taken
# 0     column1  0.000000 -1.200000  Yeo-Johnson Transformation
# 1     column3  1.293234  2.916667          Log Transformation
# 2     column4  0.000000  2.000000  Yeo-Johnson Transformation

# %%
# Code for CP00_displaying transformed datset
CP00_sample_data_encoded.head(5)
# Out:
#   column2   column1   column3   column4
# 2    None  0.055343  1.252763  1.560205
# 3       A  0.727399  1.252763  0.013805
# 1       B -0.669761  0.916291  0.013805
# 0       A -1.472976  1.252763 -1.601621
# 4       B  1.359996  1.704748  0.013805

# %% [markdown]
# # Clustor Analysis

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# ## KMeans Clustor Analysis

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import OrdinalEncoder

# Copy of the encoded DataFrame for clustering
CP00_sample_data_cluster = CP00_sample_data_encoded.copy()

# Ensure all categorical columns are numeric using OrdinalEncoder
encoder = OrdinalEncoder()
CP00_sample_data_cluster[CP00_categorical_columns] = encoder.fit_transform(
    CP00_sample_data_cluster[CP00_categorical_columns].astype(str)
)

# Ensure all columns are numeric
clustering_columns = CP00_categorical_columns + CP00_non_categorical_columns
for col in clustering_columns:
    CP00_sample_data_cluster[col] = pd.to_numeric(CP00_sample_data_cluster[col], errors='coerce')

# Drop rows with any NaN values
CP00_sample_data_cluster.dropna(subset=clustering_columns, inplace=True)

# Adjust k values based on dataset size
max_clusters = min(len(CP00_sample_data_cluster) - 1, 6)  # Ensure valid cluster range
CP00_k_values = range(2, max_clusters + 1)

# Initialize lists to store silhouette scores
CP00_silhouette_scores = []

# Iterate over the range of cluster numbers
for CP00_k in CP00_k_values:
    # Initialize KMeans with the current number of clusters
    CP00_kmeans = KMeans(n_clusters=CP00_k, random_state=55002, n_init=10)

    # Fit the model and predict cluster labels
    CP00_cluster_labels = CP00_kmeans.fit_predict(CP00_sample_data_cluster[clustering_columns])

    # Calculate the silhouette score and append it to the list
    CP00_silhouette_scores.append(
        silhouette_score(CP00_sample_data_cluster[clustering_columns], CP00_cluster_labels)
    )

# Display silhouette scores
for k, score in zip(CP00_k_values, CP00_silhouette_scores):
    print(f"Silhouette score for {k} clusters: {score:.2f}")
# Out:
# Silhouette score for 2 clusters: 0.25
# Silhouette score for 3 clusters: 0.20
# Silhouette score for 4 clusters: 0.14

# %% [markdown]
# ## Elbow Plot

# %%
import matplotlib.pyplot as plt

# Enhanced Silhouette Score Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better visibility
plt.plot(CP00_k_values, CP00_silhouette_scores, marker='o', linestyle='--', color='b', linewidth=2)
plt.scatter(CP00_k_values, CP00_silhouette_scores, color='red', label='Silhouette Points')  # Highlight individual points

# Titles and Labels
plt.title('Silhouette Scores for Optimal Cluster Determination', fontsize=16, fontweight='bold')
plt.xlabel('Number of Clusters (k)', fontsize=14)
plt.ylabel('Silhouette Score', fontsize=14)

# Adding annotations for each score
for i, score in enumerate(CP00_silhouette_scores):
    plt.text(CP00_k_values[i], score, f'{score:.2f}', fontsize=10, ha='center', va='bottom')

# Grid, Legend, and Styling
plt.grid(visible=True, linestyle='--', alpha=0.7)
plt.legend(fontsize=12, loc='best')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# # Agglomerative Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# Step 1: Extract relevant columns for clustering
CP00_clustering_data = CP00_sample_data_cluster[CP00_columns]

# Step 2: Perform hierarchical clustering (Ward's method)
CP00_linkage_matrix = linkage(CP00_clustering_data, method='ward')

# Step 3: Plot the dendrogram
plt.figure(figsize=(12, 8))  # Set figure size
dendrogram(
    CP00_linkage_matrix,
    leaf_rotation=90,  # Rotate leaf labels for readability
    leaf_font_size=10,  # Adjust font size for readability
    color_threshold=0.7 * max(CP00_linkage_matrix[:, 2])  # Set threshold for color differentiation
)
plt.title('Hierarchical Clustering Dendrogram', fontsize=16, fontweight='bold')
plt.xlabel('Sample Index or Cluster Size', fontsize=14)
plt.ylabel('Distance', fontsize=14)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Dendrogram Plot

# %%
# Step 3: Plot the enhanced dendrogram
plt.figure(figsize=(14, 10))  # Increased figure size for better visibility
dendrogram(
    CP00_linkage_matrix,
    labels=CP00_clustering_data.index,  # Use sample indices as labels
    leaf_rotation=45,  # Rotate labels at a 45-degree angle for readability
    leaf_font_size=12,  # Increased font size for labels
    color_threshold=0.7 * max(CP00_linkage_matrix[:, 2]),  # Add color threshold
    above_threshold_color='grey',  # Color for non-clustered segments
    orientation='top'  # Place the dendrogram horizontally
)
plt.title('Enhanced Dendrogram for Hierarchical Clustering', fontsize=18, fontweight='bold', color='darkblue')
plt.xlabel('Samples or Cluster Size', fontsize=14, color='darkgreen')
plt.ylabel('Euclidean Distance', fontsize=14, color='darkred')
plt.grid(visible=True, linestyle='--', alpha=0.6)  # Add a semi-transparent grid
plt.tight_layout()  # Adjust layout to fit all labels
plt.show()
